# %% [markdown]
# # 載入套件

# %%
# !pip install opencv-contrib-python -U
# Out:
# Requirement already up-to-date: opencv-contrib-python in /usr/local/lib/python3.7/dist-packages (4.5.2.52)
# Requirement already satisfied, skipping upgrade: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-contrib-python) (1.19.5)

# %%
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import cv2
import numpy as np
print(cv2.__version__)
# Out:
# 4.5.2

# %% [markdown]
# # 使用不同的threshold值來看`lena.bmp`的檢測結果

# %%
#邊緣檢測
o=cv2.imread("lena.bmp",cv2.IMREAD_GRAYSCALE)
r1=cv2.Canny(o,128,200)
r2=cv2.Canny(o,32,128)
cv2_imshow(o)
cv2_imshow(r1)
cv2_imshow(r2)
# Out:
# <PIL.Image.Image image mode=L size=195x260 at 0x7FAD63D02CD0>
# <PIL.Image.Image image mode=L size=195x260 at 0x7FAD63D02BD0>
# <PIL.Image.Image image mode=L size=195x260 at 0x7FAD63D02BD0>
